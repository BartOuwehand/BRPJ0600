# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy import wcs
from astropy.io import ascii
from astropy.table import Table, Column, MaskedColumn
from pathlib import Path
from math import trunc
from scipy import optimize
import copy
# %matplotlib inline

# %%
def hulst(a,n,wl):
    p = 4*np.pi*a*(n-1)/wl
    return 2 - ((4/p)*np.sin(p)) + ((2/p)**2 * (1-np.cos(p)))

# %%
wl_arr = np.arange(10,10000,0.1) * 1e-9 # m
sizes = np.arange(1,10,1) * 1e-7 #m


fig, axs = plt.subplots(len(sizes), sharex=True, gridspec_kw={'hspace': 0})
fig.set_figheight(3*len(sizes))
fig.set_figwidth(16)
for i in range(len(sizes)):
    axs[i].plot(wl_arr,hulst(a,0,wl_arr))
    axs[i].set_yscale('log')
axs[i].xscale('log')
axs[i].invert_xaxis()

# Hide x labels and tick labels for all but bottom plot.
for ax in axs:
    ax.label_outer()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-f115b2518305> in <module>
#       9     axs[i].plot(wl_arr,hulst(a,0,wl_arr))
#      10     axs[i].set_yscale('log')
# ---> 11 axs[i].xscale('log')
#      12 axs[i].invert_xaxis()
#      13
#
# AttributeError: 'AxesSubplot' object has no attribute 'xscale'
